# %% [markdown]
# # Vibe Coding: Real-World Data Cleaning Challenge
#
# ## The Mission
#
# You're a Data Analyst at **TechSalary Insights**. Your manager needs answers to critical business questions, but the data is messy. Your job is to clean it and provide accurate insights.
#
# **The catch:** You must figure out how to clean the data yourself. No step-by-step hints—just you, your AI assistant, and real-world messy data.
#
# ---
#
# ## The Dataset: Ask A Manager Salary Survey 2021
#
# **Location:** `../Week-02-Pandas-Part-2-and-DS-Overview/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`
#
# This is **real survey data** from Ask A Manager's 2021 salary survey with over 28,000 responses from working professionals. The data comes from this survey: https://www.askamanager.org/2021/04/how-much-money-do-you-make-4.html
#
# **Why this dataset is perfect for vibe coding:**
# - Real human responses (inconsistent formatting)
# - Multiple currencies and formats
# - Messy job titles and location data
# - Missing and invalid entries
# - Requires business judgment calls
#
# ---
#
# ## Your Business Questions
#
# Answer these **exact questions** with clean data. There's only one correct answer for each:
#
# ### Core Questions (Required):
# 1. **What is the median salary for Software Engineers in the United States?**
# 2. **Which US state has the highest average salary for tech workers?**
# 3. **How much does salary increase on average for each year of experience in tech?**
# 4. **Which industry (besides tech) has the highest median salary?**
#
# ### Bonus Questions (If time permits):
# 5. **What's the salary gap between men and women in tech roles?**
# 6. **Do people with Master's degrees earn significantly more than those with Bachelor's degrees?**
#
# **Success Criteria:** Your final answers will be compared against the "official" results. Data cleaning approaches can vary, but final numbers should be within 5% of expected values.

# %% [markdown]
# **Examples of Ineffective Prompts:**
# - "Clean my data" (too vague)
# - "Fix all the problems" (no specific direction)
# - "Make this work" (doesn't explain the goal)
#
# ### Your Mission Strategy
#
# 1. **Explore systematically** - Understand the data structure and identify issues
# 2. **Clean incrementally** - Handle one data quality problem at a time
# 3. **Validate constantly** - Check that your cleaning makes business sense
# 4. **Answer precisely** - Use clean data to get accurate business insights
#
# **Remember:** Multiple cleaning approaches are valid, but there's only one correct final answer for each business question.

# %% [markdown]
# ## Expected Results (For Validation)
#
# When you're done cleaning and analyzing, your answers should be close to these ranges:
#
# 1. **Software Engineer median salary:** $125,000 - $140,000
# 2. **Highest paying tech state:** California, Washington, or New York
# 3. **Experience salary increase:** $1,000 - $2,000 per year
# 4. **Highest non-tech industry:** Law, Finance, or Consulting
#
# *Note: Exact numbers depend on your cleaning decisions, but should be in these ballparks*
#
# ---
#
# ## Submission Requirements
#
# ### What to Submit:
# 1. **This completed notebook** with all your code and analysis
# 2. **Your Cursor plan** (copy from chat/todos and paste as markdown)
# 3. **Your final answers** clearly stated
# 4. **Brief explanation** of major cleaning decisions
#
# ### Evaluation Criteria:
# - **Correctness (50%):** Did you get reasonable answers within expected ranges?
# - **Process (30%):** Did you use Cursor effectively and work systematically?
# - **Code Quality (20%):** Is your code readable, well-commented, and reproducible?
#
# ### How to Submit Your Plan:
# **In Cursor:** Create your plan using chat or todos
# **In your notebook:** Copy and paste your plan into the designated markdown cell below
# **Update status:** Check off completed items as you work
#
# **Pro Tip:** Document major decisions like "I converted all currencies to USD using 2021 rates" or "I excluded salaries above $500K as likely data entry errors"

# %% [markdown]
# ---
# # Your Work Starts Here
#
# ## Step 1: Create Your Plan with Cursor
#
# **Before writing any code**, use Cursor to develop your strategy.
#
# **Try asking Cursor:**
# - "What are the typical challenges when cleaning survey data for analysis?"
# - "What steps should I follow to prepare salary data for business analysis?"
# - "What data quality issues should I watch out for in a survey dataset?"
#
# **Then create a comprehensive plan and paste it here:**
#
# ### My Data Cleaning Plan (Created with Cursor):
# <!-- Paste your plan from Cursor here -->
# - [ ] Example todo item
# - [ ] Another example
# - [ ] ...
#
# **Document your approach:** What challenges do you expect with this salary survey data?
# - What formats might salary data be in?
# - How will you identify different job roles?
# - How will you handle different currencies?
# - What constitutes valid vs invalid data?

# %% [markdown]
# ## Step 2: Load and Explore the Dataset
#
# Start by loading the data and understanding its structure. What columns exist? What do the first few rows look like? What problems can you spot immediately?

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset from Week 2 folder
# File path: '../Week-02-Pandas-Part-2-and-DS-Overview/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'

# Your exploration code here
# Start by loading the data and examining its structure

# %% [markdown]
# ## Step 3: Data Cleaning
#
# Now for the main challenge! You've identified the problems—time to solve them systematically.
#
# **Think about these challenges as you work:**
# - How will you make all salaries comparable?
# - What counts as a "Software Engineer"?
# - How will you identify "tech workers" vs other industries?
# - What constitutes valid vs invalid data?
#
# **Work incrementally:** Clean one issue at a time and check your results before moving on.

# %%
# Your data cleaning code here
# 
# Consider these challenges:
# - Salary values may have different formats ($50,000 vs 50000 vs $45K-$55K)
# - Multiple currencies need standardization  
# - Job titles are inconsistent ("Software Engineer" vs "software engineer" vs "SWE")
# - Location data has variations ("NY" vs "New York" vs "New York State")
# - Experience may be in ranges ("5-7 years") or categories
#
# Work systematically and validate each step!

# %% [markdown]
# ## Step 4: Answer the Business Questions
#
# With your cleaned data, now answer each business question precisely.
#
# **Important:** Make sure to clearly document your final answers - these will be checked for accuracy!

# %%
# Question 1: What is the median salary for Software Engineers in the United States?
# 
# Consider: What job titles count as "Software Engineer"? 
# How will you filter for US-based respondents?
# How will you ensure salary data is clean and comparable?

# %%
# Question 2: Which US state has the highest average salary for tech workers?
#
# Consider: What industries/jobs count as "tech"?
# How will you handle states with very few responses?
# Should you use mean or median for "average"?

# %%
# Question 3: How much does salary increase on average for each year of experience in tech?
#
# Consider: How will you convert experience ranges to numbers?
# What's the best way to measure this relationship?
# Should you include all experience levels or focus on early-career?

# %%
# Question 4: Which industry (besides tech) has the highest median salary?
#
# Consider: What industries should be excluded as "tech"?
# How will you ensure fair comparison across industries?
# Should you filter by sample size?

# %%
# Bonus Questions (if time permits):

# Question 5: What's the salary gap between men and women in tech roles?

# Question 6: Do people with Master's degrees earn significantly more than those with Bachelor's degrees?

# %%
# Space for additional analysis or validation

# %% [markdown]
# ## Your Final Answers
#
# **Clearly state your final answers here:**
#
# 1. **Median salary for Software Engineers in US:** $______
# 2. **US state with highest average tech salary:** ______
# 3. **Salary increase per year of experience in tech:** $______ per year
# 4. **Industry with highest median salary (non-tech):** ______
#
# **Bonus answers (if completed):**
# 5. **Gender salary gap in tech:** ______
# 6. **Master's vs Bachelor's salary difference:** ______
#
# ---
#
# ## Reflection
#
# **What were the biggest data quality challenges?**
#
# **What cleaning decisions did you make and why?**
#
# **How did vibe coding help or hinder your work?**
#
# **What would you do differently next time?**
