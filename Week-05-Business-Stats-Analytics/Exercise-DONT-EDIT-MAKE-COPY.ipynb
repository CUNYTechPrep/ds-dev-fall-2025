# %% [markdown]
# # Week 5 Exercise: Business Statistics Analytics
# ## IBM HR Analytics Employee Attrition Dataset
#
# **Objective:** Apply statistical methods from Week 5 to analyze employee data and answer business questions.
#
# **Dataset:** `data/WA_Fn-UseC_-HR-Employee-Attrition.csv`
# **Source:** IBM HR Analytics Employee Attrition (fictional dataset created by IBM data scientists)
# **Size:** 1,470 employees, 35 features
# **Business Context:** Uncover factors that lead to employee attrition and explore workforce analytics questions.
#
# ---
#
# ## Dataset Overview
#
# This dataset contains employee information including:
# - **Demographics:** Age, Gender, MaritalStatus, EducationField
# - **Job Information:** Department, JobRole, JobLevel, MonthlyIncome
# - **Satisfaction Metrics:** JobSatisfaction, EnvironmentSatisfaction, WorkLifeBalance
# - **Attrition:** Whether the employee left the company (Yes/No)
# - **Work Patterns:** OverTime, BusinessTravel, DistanceFromHome
#
# ### Key Variable Encodings:
# - **Education:** 1='Below College', 2='College', 3='Bachelor', 4='Master', 5='Doctor'
# - **JobSatisfaction:** 1='Low', 2='Medium', 3='High', 4='Very High'
# - **WorkLifeBalance:** 1='Bad', 2='Good', 3='Better', 4='Best'
# - **PerformanceRating:** 1='Low', 2='Good', 3='Excellent', 4='Outstanding'

# %% [markdown]
# ## Setup & Guidelines
#
# **Required Libraries:** pandas, numpy, scipy.stats, statsmodels, matplotlib, seaborn
#
# **Statistical Guidelines:**
# - Use **95% confidence intervals** unless stated otherwise
# - For group comparisons, always **report sample sizes** (n)
# - If any group has **n < 30**, mention it and proceed with caution
# - For proportion tests, show **counts and proportions** clearly
# - Always include **1-3 sentence interpretations** (statistical + business context)
# - State your **assumptions** and **test choices**
#
# **Important Notes:**
# - This dataset is clean with no missing values
# - Some variables are encoded as numbers but represent categories (see above)
# - Sample sizes are generally adequate (n ≥ 30) for most analyses
# - Focus on **practical significance** in addition to statistical significance

# %%
# Setup Cell - Run this first
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')

# Load the dataset
df = pd.read_csv('data/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# Basic dataset info
print(f"Dataset loaded: {df.shape[0]} employees, {df.shape[1]} features")
print(f"Missing values: {df.isnull().sum().sum()}")
print("\nFirst few rows:")
df.head()

# %% [markdown]
# ## Q1: Basic Stats & Distribution
#
# Get summary stats for `MonthlyIncome`, `YearsAtCompany`, and `JobSatisfaction`.
#
# Then make a histogram of `MonthlyIncome` and see if it's skewed or has outliers.
#
# What's this tell us about the workforce?

# %%
# Your code for Question 1 here

# %% [markdown]
# ## Q2: 95% CI for Sales Income
#
# Get a 95% confidence interval for mean `MonthlyIncome` in the Sales department.
#
# Show the sample size, mean, and CI. Use bootstrap method (like in lecture).

# %%
# Your code for Question 2 here

# %% [markdown]
# ## Q3: Gender Pay Gap t-test
#
# Compare mean `MonthlyIncome` between Male vs Female employees.
#
# Do a two-sample t-test (Welch's version). Report n, means, t-stat, p-value.
#
# Is there a significant difference?

# %%
# Your code for Question 3 here

# %% [markdown]
# ## Q4: Attrition vs Overtime
#
# Test if attrition rate is different for employees who work `OverTime` vs those who don't.
#
# Make a crosstab and calculate the attrition rates for each group. Then do a chi-square test.

# %%
# Your code for Question 4 here

# %% [markdown]
# ## Q5: ANOVA - JobSatisfaction by Department
#
# Test if mean `JobSatisfaction` is different across the 3 departments.
#
# Check sample sizes first (all should be n ≥ 40). Then do one-way ANOVA.

# %%
# Your code for Question 5 here

# %% [markdown]
# ## Q6: Chi-square - EducationField vs JobRole
#
# Test if there's an association between `EducationField` and `JobRole`.
#
# Filter to top 4 education fields and top 6 job roles (use `.value_counts().head()`). Make contingency table with `pd.crosstab()` and do chi-square test.

# %%
# Your code for Question 6 here

# %% [markdown]
# ## Q7: Correlation - Age vs YearsAtCompany
#
# Get the Pearson correlation between `Age` and `YearsAtCompany`.
#
# Make a scatter plot with trend line (use `plt.scatter()` and `np.polyfit()`). Report correlation and p-value.

# %%
# Your code for Question 7 here

# %% [markdown]
# ## Q8: Regression - Predict MonthlyIncome
#
# Build a regression model: `MonthlyIncome ~ YearsAtCompany + OverTime`
#
# Create dummy for OverTime (1 for Yes, 0 for No), add constant with `sm.add_constant()`, fit OLS model. Report coefficients and R-squared.

# %%
# Your code for Question 8 here

# %% [markdown]
# ## Q9: Sales Executive Analysis
#
# Within Sales Executives only, compare `YearsAtCompany` between those who left vs stayed.
#
# Filter for Sales Executive role, then do t-test on YearsAtCompany by Attrition status.

# %%
# Your code for Question 9 here
